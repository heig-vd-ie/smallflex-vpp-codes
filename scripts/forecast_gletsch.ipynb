# %%
from federation.generate_scenarios import query_time_series_data, fill_null_remove_outliers, generate_scenarios
from schema.schema import DischargeFlow
DB_CACHE_FILE = r"../.cache/interim/time_series_schema.db"
data = query_time_series_data(DB_CACHE_FILE, river="Gletsch", tables=[DischargeFlow])["DischargeFlow"]
data = fill_null_remove_outliers(data, d_time="1h", z_score=10)
data_scenarios1 = generate_scenarios(data)

# %%
import polars as pl
arbitrary_year = pl.col("timestamp").dt.strftime("2030-%m-%d %H:%M:%S").str.strptime(pl.Datetime, format="%Y-%m-%d %H:%M:%S", strict=False)
df = data_scenarios1.filter(pl.col("scenario")=="median").with_columns(arbitrary_year).sort("timestamp").select(["timestamp", "value"]).to_pandas().set_index("timestamp", drop=True)# .asfreq('30Min', method = 'ffill')
data_df1 = df[~df.index.duplicated()].asfreq('1H', method = 'ffill')

# %%
import warnings
import numpy as np
from sktime.forecasting.base import ForecastingHorizon
from pycaret.datasets import get_data
from pycaret.time_series import *
exp1 = TSForecastingExperiment()
warnings.filterwarnings("ignore")
fh = ForecastingHorizon(values=np.arange(24,48), is_relative=True)
s1 = exp1.setup(
    data=data_df1, fh=fh, fold=12, session_id=41
)
# Out:
# <style type="text/css">
# #T_ed7b1_row25_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ed7b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed7b1_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ed7b1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed7b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ed7b1_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_ed7b1_row0_col1" class="data row0 col1" >41</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ed7b1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ed7b1_row1_col1" class="data row1 col1" >value</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ed7b1_row2_col0" class="data row2 col0" >Approach</td>
#       <td id="T_ed7b1_row2_col1" class="data row2 col1" >Univariate</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ed7b1_row3_col0" class="data row3 col0" >Exogenous Variables</td>
#       <td id="T_ed7b1_row3_col1" class="data row3 col1" >Not Present</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ed7b1_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_ed7b1_row4_col1" class="data row4 col1" >(8712, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ed7b1_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_ed7b1_row5_col1" class="data row5 col1" >(8712, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ed7b1_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_ed7b1_row6_col1" class="data row6 col1" >(8665, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ed7b1_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_ed7b1_row7_col1" class="data row7 col1" >(24, 1)</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ed7b1_row8_col0" class="data row8 col0" >Rows with missing values</td>
#       <td id="T_ed7b1_row8_col1" class="data row8 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ed7b1_row9_col0" class="data row9 col0" >Fold Generator</td>
#       <td id="T_ed7b1_row9_col1" class="data row9 col1" >ExpandingWindowSplitter</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ed7b1_row10_col0" class="data row10 col0" >Fold Number</td>
#       <td id="T_ed7b1_row10_col1" class="data row10 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ed7b1_row11_col0" class="data row11 col0" >Enforce Prediction Interval</td>
#       <td id="T_ed7b1_row11_col1" class="data row11 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ed7b1_row12_col0" class="data row12 col0" >Splits used for hyperparameters</td>
#       <td id="T_ed7b1_row12_col1" class="data row12 col1" >all</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ed7b1_row13_col0" class="data row13 col0" >User Defined Seasonal Period(s)</td>
#       <td id="T_ed7b1_row13_col1" class="data row13 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ed7b1_row14_col0" class="data row14 col0" >Ignore Seasonality Test</td>
#       <td id="T_ed7b1_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ed7b1_row15_col0" class="data row15 col0" >Seasonality Detection Algo</td>
#       <td id="T_ed7b1_row15_col1" class="data row15 col1" >auto</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ed7b1_row16_col0" class="data row16 col0" >Max Period to Consider</td>
#       <td id="T_ed7b1_row16_col1" class="data row16 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ed7b1_row17_col0" class="data row17 col0" >Seasonal Period(s) Tested</td>
#       <td id="T_ed7b1_row17_col1" class="data row17 col1" >[24, 48, 23, 25, 2, 47, 49, 22, 46, 26, 50, 3, 45, 27, 51, 21, 4, 52, 28, 44, 20]</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ed7b1_row18_col0" class="data row18 col0" >Significant Seasonal Period(s)</td>
#       <td id="T_ed7b1_row18_col1" class="data row18 col1" >[24, 48, 23, 25, 2, 47, 49, 22, 46, 26, 50, 3, 45, 27, 51, 21, 4, 52, 28, 44, 20]</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ed7b1_row19_col0" class="data row19 col0" >Significant Seasonal Period(s) without Harmonics</td>
#       <td id="T_ed7b1_row19_col1" class="data row19 col1" >[48, 46, 50, 52, 47, 49, 44, 51, 45, 27, 21, 28, 20]</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_ed7b1_row20_col0" class="data row20 col0" >Remove Harmonics</td>
#       <td id="T_ed7b1_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_ed7b1_row21_col0" class="data row21 col0" >Harmonics Order Method</td>
#       <td id="T_ed7b1_row21_col1" class="data row21 col1" >harmonic_max</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_ed7b1_row22_col0" class="data row22 col0" >Num Seasonalities to Use</td>
#       <td id="T_ed7b1_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_ed7b1_row23_col0" class="data row23 col0" >All Seasonalities to Use</td>
#       <td id="T_ed7b1_row23_col1" class="data row23 col1" >[24]</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_ed7b1_row24_col0" class="data row24 col0" >Primary Seasonality</td>
#       <td id="T_ed7b1_row24_col1" class="data row24 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_ed7b1_row25_col0" class="data row25 col0" >Seasonality Present</td>
#       <td id="T_ed7b1_row25_col1" class="data row25 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_ed7b1_row26_col0" class="data row26 col0" >Seasonality Type</td>
#       <td id="T_ed7b1_row26_col1" class="data row26 col1" >mul</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_ed7b1_row27_col0" class="data row27 col0" >Target Strictly Positive</td>
#       <td id="T_ed7b1_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_ed7b1_row28_col0" class="data row28 col0" >Target White Noise</td>
#       <td id="T_ed7b1_row28_col1" class="data row28 col1" >No</td>
#     </tr>
#     <tr>
#       <th id="T_ed7b1_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_ed7b1_row29_col0" cl

# %%
from sktime.forecasting.auto_reg import AutoREG  
autoreg_sktime = AutoREG(lags=[i for i in range(24, 72)], trend="n") 
arima1 = exp1.create_model(autoreg_sktime, fit_kwargs={"fh": "{fh}"})
# Out:
# <style type="text/css">
# #T_6b76f_row12_col0, #T_6b76f_row12_col1, #T_6b76f_row12_col2, #T_6b76f_row12_col3, #T_6b76f_row12_col4, #T_6b76f_row12_col5, #T_6b76f_row12_col6, #T_6b76f_row12_col7 {
#   background: yellow;
# }
# </style>
# <table id="T
td>
#     </tr>
#     <tr>
#       <th id="T_6b76f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6b76f_row5_col0" class="data row5 col0" >2030-12-22 01:00</td>
#       <td id="T_6b76f_row5_col1" class="data row5 col1" >0.0080</td>
#       <td id="T_6b76f_row5_col2" class="data row5 col2" >0.0036</td>
#       <td id="T_6b76f_row5_col3" class="data row5 col3" >0.0041</td>
#       <td id="T_6b76f_row5_col4" class="data row5 col4" >0.0047</td>
#       <td id="T_6b76f_row5_col5" class="data row5 col5" >0.0116</td>
#       <td id="T_6b76f_row5_col6" class="data row5 col6" >0.0117</td>
#       <td id="T_6b76f_row5_col7" class="data row5 col7" >-3.4824</td>
#     </tr>
#     <tr>
#       <th id="T_6b76f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6b76f_row6_col0" class="data row6 col0" >2030-12-23 01:00</td>
#       <td id="T_6b76f_row6_col1" class="data row6 col1" >0.0102</td>
#       <td id="T_6b76f_row6_col2" class="data row6 col2" >0.0046</td>
#       <td id="T_6b76f_row6_col3" class="data row6 col3" >0.0052</td>
#       <td id="T_6b76f_row6_col4" class="data row6 col4" >0.0059</td>
#       <td id="T_6b76f_row6_col5" class="data row6 col5" >0.0146</td>
#       <td id="T_6b76f_row6_col6" class="data row6 col6" >0.0147</td>
#       <td id="T_6b76f_row6_col7" class="data row6 col7" >-2.6782</td>
#     </tr>
#     <tr>
#       <th id="T_6b76f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6b76f_row7_col0" class="data row7 col0" >2030-12-24 01:00</td>
#       <td id="T_6b76f_row7_col1" class="data row7 col1" >0.0508</td>
#       <td id="T_6b76f_row7_col2" class="data row7 col2" >0.0365</td>
#       <td id="T_6b76f_row7_col3" class="data row7 col3" >0.0260</td>
#       <td id="T_6b76f_row7_col4" class="data row7 col4" >0.0468</td>
#       <td id="T_6b76f_row7_col5" class="data row7 col5" >0.0609</td>
#       <td id="T_6b76f_row7_col6" class="data row7 col6" >0.0667</td>
#       <td id="T_6b76f_row7_col7" class="data row7 col7" >-0.3977</td>
#     </tr>
#     <tr>
#       <th id="T_6b76f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6b76f_row8_col0" class="data row8 col0" >2030-12-25 01:00</td>
#       <td id="T_6b76f_row8_col1" class="data row8 col1" >0.0291</td>
#       <td id="T_6b76f_row8_col2" class="data row8 col2" >0.0137</td>
#       <td id="T_6b76f_row8_col3" class="data row8 col3" >0.0148</td>
#       <td id="T_6b76f_row8_col4" class="data row8 col4" >0.0175</td>
#       <td id="T_6b76f_row8_col5" class="data row8 col5" >0.0453</td>
#       <td id="T_6b76f_row8_col6" class="data row8 col6" >0.0439</td>
#       <td id="T_6b76f_row8_col7" class="data row8 col7" >-1.7738</td>
#     </tr>
#     <tr>
#       <th id="T_6b76f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6b76f_row9_col0" class="data row9 col0" >2030-12-26 01:00</td>
#       <td id="T_6b76f_row9_col1" class="data row9 col1" >0.0413</td>
#       <td id="T_6b76f_row9_col2" class="data row9 col2" >0.0215</td>
#       <td id="T_6b76f_row9_col3" class="data row9 col3" >0.0210</td>
#       <td id="T_6b76f_row9_col4" class="data row9 col4" >0.0275</td>
#       <td id="T_6b76f_row9_col5" class="data row9 col5" >0.0626</td>
#       <td id="T_6b76f_row9_col6" class="data row9 col6" >0.0596</td>
#       <td id="T_6b76f_row9_col7" class="data row9 col7" >-2.4556</td>
#     </tr>
#     <tr>
#       <th id="T_6b76f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6b76f_row10_col0" class="data row10 col0" >2030-12-27 01:00</td>
#       <td id="T_6b76f_row10_col1" class="data row10 col1" >0.0209</td>
#       <td id="T_6b76f_row10_col2" class="data row10 col2" >0.0093</td>
#       <td id="T_6b76f_row10_col3" class="data row10 col3" >0.0106</td>
#       <td id="T_6b76f_row10_col4" class="data row10 col4" >0.0118</td>
#       <td id
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
data1 = exp1.plot_model(arima1, plot="insample", return_data=True)
